# %% [markdown]
# # Threshold algorithm

# %%
import random
import networkx as nx
import numpy as np

# %%
class Threshold:
    def __init__(self, graph):
        self._graph = graph
        self._n = nx.number_of_nodes(self._graph)
        
    def set_opinions(self, opinion0_count):
        opinions = [0]*opinion0_count + [1]*(self._n-opinion0_count)
        random.shuffle(opinions)
        d = {list(self._graph.nodes())[i] : opinions[i] for i in range(self._n)}
        nx.set_node_attributes(self._graph, d, 'state')
        
    #maybe z dupy
    def set_epsilon(self, e_list):
        node_list = list(self._graph.nodes())
        d = {node_list[i]: e_list[i] for i in range(len(node_list))}
        nx.set_node_attributes(self._graph, d, 'epsilon')
        
    def set_threshold_basic(self, p):
        d = {node: p for node in list(self._graph.nodes())}
        nx.set_node_attributes(self._graph, d, 'threshold')
        
    def set_threshold(self, p_list):
        node_list = list(self._graph.nodes())
        d = {node_list[i]: p_list[i] for i in range(len(node_list))}
        nx.set_node_attributes(self._graph, d, 'threshold')
    
    def threshold_algorithm(self, q, max_steps):
        node_states = [0, 1]
        step = 0
        while node_states != [0] and node_states != [1] and step < max_steps:
            node = random.choice(list(self._graph.nodes()))
            curr_q = q
            if q > self._graph.degree[node]:
                curr_q = self._graph.degree[node]
            neighbor_list = random.choices(list(self._graph.neighbors(node)), k=curr_q) #add weighted edges and choice with weight
            node_opinion = self._graph.nodes[node]['state']
            contrary_opinion = 0 if node_opinion == 1 else 1
            op0_num = (self._n - list(nx.get_node_attributes(self._graph, 'state').values()).count(node_opinion))/self._n
            if op0_num >= self._graph.nodes[node]['threshold'] or \
               (random.uniform(0, 1) < self._graph.nodes[node]['epsilon'] and op0_num > 0):
                self._graph.nodes[node]['state'] = contrary_opinion
            node_states = list(set(list(nx.get_node_attributes(self._graph, 'state').values())))
            step += 1
        return self._graph, step

# %%
RG = nx.erdos_renyi_graph(50, 0.5)

# %%
dupa = Threshold(RG)

# %%
dupa.set_opinions(20)

# %%
dupa.set_threshold(np.random.uniform(0.1, 0.9, 50))

# %%
dupa.set_epsilon(np.random.uniform(0.0001, 0.001, 50))

# %%
colors = {0:'red', 1:'blue'}
labels = nx.get_node_attributes(RG, 'state')
node_color = [colors[state] for state in labels.values()]
nx.draw(RG, labels=labels, node_color=node_color)

# %%
newRG, s = dupa.threshold_algorithm(5, 1000)

# %%
labels = nx.get_node_attributes(newRG, 'state')
node_color = [colors[state] for state in labels.values()]
nx.draw(newRG, labels=labels, node_color=node_color)

# %%
s
# Out:
# 128
